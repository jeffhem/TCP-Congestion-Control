# %% [markdown]
# <center><h1>Performance Study of TCP Congestion Control</h1><center>
#
# ### <center>EE 382N, Spring 2019</center> <center>Cheuk Ng (cn9475)</center>

# %%
run -i ./src/plot_tcpprobe.py reno 21

# %%
run -i ./src/plot_tcpprobe.py reno 81

# %%
run -i ./src/plot_tcpprobe.py reno 162

# %%
run -i plot_fairness.py reno 21
